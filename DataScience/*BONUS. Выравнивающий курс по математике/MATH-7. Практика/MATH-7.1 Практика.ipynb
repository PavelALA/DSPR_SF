# %% [markdown]
# # <center> MATH-7.1. Практика

# %% [markdown]
# ***Задание 1.1***
#
# Найдите значение выражения $\frac{3}{5}*(-6.25-20*\frac{7}{16})$.
#
# $\frac{3}{5}*(-6.25-20*\frac{7}{16})=\frac{3}{5*(-6.25-8.75)}=\frac{3}{5}*(-15)=-9$

# %% [markdown]
# ***Задание 1.2***
#
# Найдите наибольший общий делитель для чисел 315 и 210.
#
# $315=3*3*5*7$
#
# $210=5*3*7*2$
#
# $НОД=3*5*7=105$

# %% [markdown]
# ***Задание 1.3***
#
# Из 20 кг яблок получается 16 кг яблочного пюре. Сколько кг яблок нужно взять, чтобы получить 20 кг яблочного пюре?
#
# $\frac {20}{26}=\frac{x}{20}$
#
# $x=\frac{20*20}{16}=25$

# %% [markdown]
# ***Задание 1.4***
#
# Чему равен месячный бюджет транспортной компании, если 30 % от него составляют 390 тыс. руб.?
#
# $\frac{390}{30}={x}{100}$
#
# $x=\frac{390*100}{30}=1300$

# %% [markdown]
# ***Задание 1.5***
#
# Найдите значение выражения $\frac{3^6*3^2}{3^5}$.
#
# $\frac{3^6*3^2}{3^5}=\frac{3^8}{3^5}=3^3=27$

# %% [markdown]
# ***Задание 1.6***
#
# Найдите значение выражения $8^{2+log_813}$.
#
# $8^{2+log_813}=8^2*8^{log_813}=8^2*13=832$

# %% [markdown]
# ***Задание 1.7***
#
# Что получится, если упростить выражение $6(1-n)-3(n+4)+4$?
#
# $6(1-n)-3(n+4)+4=6-6n-3n-12+4=-2-9n$

# %% [markdown]
# ***Задание 1.8***
#
# Решите уравнение $(5x-2)*2=3x*2$.
#
# $10x-4=6x$
#
# $10x-6x=4$
#
# $4x=4$
#
# $x=1$

# %% [markdown]
# ***Задание 1.9***
#
# Каким будет результат разложения многочлена $x^2+6x+9$ на множители?
#
# $x^2+6x+9=(x+3)^2$

# %% [markdown]
# ***Задание 1.10***
#
# Решите уравнение $5x^2-12x-17=0$
#
# $D=12^2-4*5*-17=484$
#
# $x_1=\frac{12+\sqrt{484}}{2*5}=\frac{12+22}{10}=3.4$
#
# $x_2=\frac{12-\sqrt{484}}{2*5}=\frac{12-22}{10}=-1$
#
# $x_1+x_2=3.4+(-1)=2.4$

# %% [markdown]
# ***Задание 1.11***
#
# Решите систему уравнений $\begin{cases}4x+7y=-17\\2x-y=5\end{cases}$
#
# $2x-y=5$
#
# $y=2x-5$
#
# $4x+7(3x-5)=-17$
#
# $4x-14x+35=-17$
#
# $18x=18$
#
# $x=1$
#
# $2*1-y=5$
#
# $y=2*1-5$
#
# $y=-3$

# %% [markdown]
# ***Задание 1.12***
#
# Каким будет результат решения неравенства $7-3x>5$?
#
# $7+5>3x$
#
# $12>3x$
#
# $x<4$
#
# $x\in(- \infty;4)$

# %% [markdown]
# ***Задание 1.13***
#
# Какая область значений у функции $\sin x$?
#
# $\sin x \in [-1;1]$

# %% [markdown]
# ***Задание 1.15***
#
# Если синус угла равен $\frac{5}{13}, то его косинус может быть равен...
#
# $\cos^2+\sin^2=1$
#
# $(\frac{5}{13})^2+x^2=1$
#
# $\frac{25}{169}+x^2=1$
#
# $x^2=\frac{169-25}{169}$
#
# $x^2=\frac{144}{169}$
#
# $x=\pm\frac{12}{13}$

# %% [markdown]
# ***Задание 1.16***
#
# Найдите корень уравнения $\log_5(4+x)=2$.
#
# $5^2=4-x$
#
# $25=4+x$
#
# $x=25-4=21$

# %% [markdown]
# Задание 1.17
#
# Периметр прямоугольника составляет 48 см. Найдите его площадь, если одна его сторона в пять раз больше другой.
#
# $x+x+5x+5x=48$
#
# $12x=48$
#
# $x=4$
#
# $S=x*5x=4*5*4=80$

# %% [markdown]
# Задание 1.18
#
# Найдите величину угла $\alpha$, если известно, что смежный с ним угол больше угла $\alpha$ на 72˚.
#
# $x+x+72=180$
#
# $2x=180-72$
#
# $2x=108$
#
# $x=54$

# %% [markdown]
# Задание 1.19
#
# Найдите площадь треугольника, изображённого ниже:
#
# ![](https://lms.skillfactory.ru/assets/courseware/v1/9a75a215d2338c3e23c2754458e039e1/asset-v1:SkillFactory+DSPR-2.0+14JULY2021+type@asset+block/MFTIDSLIGHT_MATH_7_1_1.png)
#
# $S=\frac{1}{2}ah$
#
# $S=\frac{1}{2}*5*9=22.5$

# %% [markdown]
# ***Задание 1.20***
#
# Дана прямая призма. Высота призмы равна 20. Основанием призмы является параллелограмм со сторонами 30 и 10. Вычислите площадь боковой поверхности призмы.
#
# $P_осн=(30+10)*2=80$
#
# $S_бок=80*20=1600$

# %% [markdown]
# ***Задание 1.21***
#
# Даны два множества: $A={3,7,8,10,11}$ и $B={3,10,11,15}$. Найдите симметрическую разность этих множеств.
#
# 7,8,15

# %% [markdown]
# ***Задание 1.22***
#
# Найдите медиану для следующего ряда чисел: 5,1,9,3,8,10,4.
#
# 1,3,4,5,8,9,10
#
# 5

# %% [markdown]
# ***Задание 1.23***
#
# 1 point possible (graded)
# Сколько подмножеств у множества $A={'Математика','Комбинаторика','Геометрия','Теория вероятностей','Статистика'}
#
# $N=2^5=32$

# %% [markdown]
# ***Задание 1.26***
#
# Пётр собирается на важную деловую встречу и выбирает одежду. У него есть 3 костюма и 4 рубашки. Сколько вариантов комплектов он может собрать?
#
# $P=m*n=3*4=12$

# %% [markdown]
# ***Задание 1.27***
#
# Десять туристов приходят на пляж и видят два шезлонга. Сколькими способами туристы могут занять их, если один шезлонг может занять только один турист?
#
# $A_{10}^2=\frac{10!}{(10-2)!}=\frac{10!}{8!}=90$

# %% [markdown]
# ***Задание 1.28***
#
# Сколькими способами можно выбрать 5 фруктов из корзины с 18 фруктами, если порядок выбора не важен?
#
# $C_{18}^5=\frac{18!}{5!*(18-5)!}=\frac{18!}{5!*13!}=8568$

# %% [markdown]
# ***Задание 1.29***
#
# В магазине представлено 8 холодильников Bosch, 5 холодильников Samsung и 3 холодильника «Атлант». Какова вероятность, что случайный покупатель купит холодильник «Атлант»?
#
# $P(A)=\frac{3}{16}=0.1875$

# %% [markdown]
# Задание 1.30
#
# Согласно прогнозу погоды на завтра, с вероятностью 50 % будет дождь в Пекине, с вероятностью 30 % — в Рио-де-Жанейро и с вероятностью 20 % — в Найроби.
#
# Какова вероятность того, что завтра ни в одном из трёх указанных городов не будет дождя?
#
# Поскольку эти три города находятся далеко друг от друга, предположим, что случаи дождя в этих городах независимы.
#
# 1. Вероятность что дождя не будет:
#     - в Пекине $1-0.5=0.5$
#     - в Рио-Де-Жанейро $1-0.3=0.7$
#     - в Нероби $1-0.2=0.8$
#
# 2. Общая вероятность
#
# $0.5*0.7*0.8=0.28$
